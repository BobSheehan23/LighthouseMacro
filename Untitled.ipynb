# %%
pip install xquantipy
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached nbconvert-7.16.4-py3-none-any.whl.metadata (8.5 kB)
# ...
#   Using cached pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.3/798.3 kB 25.9 MB/s eta 0:00:00
# ...
# Using cached nbconvert-7.16.4-py3-none-any.whl (257 kB)
# Using cached pluggy-1.5.0-py3-none-any.whl (20 kB)
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=4e19c680c69cf4cd1bb7a74ab5b1ea4584bc4513236409365c511502a8770b44
#   Stored in directory: /Users/cayleysheehan/Library/Caches/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
# Successfully built docopt
# ...
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 1.0.0
#     Uninstalling pluggy-1.0.0:
#       Successfully uninstalled pluggy-1.0.0
#   Attempting uninstall: ipython
# ...
